# %% [markdown]
# #### Tool

# %%
import shutil
from imutils import paths
import random
import os

# Lấy các đường dẫn đến ảnh
image_paths = list(paths.list_images('Dataset'))

# Đổi vị trí ngẫu nhiên các đường dẫn ảnh
random.shuffle(image_paths)

# Chỉ lấy 5000 dòng đầu tiên (5000 ảnh)
selected_image_paths = image_paths[:2000]

# Thư mục đích để sao chép
destination_folder = 'dataset_2000'

# Tạo thư mục đích nếu nó không tồn tại
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# Sao chép các tệp ảnh vào thư mục đích
for image_path in selected_image_paths:
    filename = os.path.basename(image_path)
    destination_path = os.path.join(destination_folder, filename)
    shutil.copyfile(image_path, destination_path)

print("Sao chép hoàn tất.")

# %% [markdown]
# #### UnZip and Create Folder

# %% [markdown]
# - File .zip sẽ là file chứa toàn bộ các ảnh tên của ảnh là nhãn ví dụ cat.1.jpg ; cat.2.jpg ; dot.1.jpg,...
# - Tạo một folder Dataset ngang hàng với file này , cho vào đó file .zip chứa toàn bộ các ảnh
# - Chạy file nó sẽ giải nén và tạo ra các folder train , val , test
# - LƯU Ý : Cần chỉnh lại : labels = ['mild', 'moderate', 'non', 'verymild'] đúng với các nhãn của tập dữ liệu

# %%
import os
import shutil
import random
import zipfile

# Giải nén tệp data_500.zip vào thư mục data_500
data_zip_path = 'Dataset/dataset_2000.zip'
data_dir = 'Dataset/dataset_2000'
root_dir = 'Dataset/'

with zipfile.ZipFile(data_zip_path, 'r') as zip_ref:
    zip_ref.extractall(root_dir)

# Đường dẫn tới thư mục con 'train', 'val' và 'test'
train_dir = os.path.join(root_dir, 'train')
val_dir = os.path.join(root_dir, 'val')
test_dir = os.path.join(root_dir, 'test')

# Tạo các thư mục con 'train', 'val' và 'test'
os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# Danh sách các nhãn
labels = ['mild', 'moderate', 'non', 'verymild'] 

# Tỷ lệ train:val:test
train_ratio = 0.7
val_ratio = 0.2
test_ratio = 0.1

# Lặp qua các nhãn
for label in labels:
    # Tạo các thư mục con 'dog' và 'cat' trong 'train', 'val' và 'test'
    os.makedirs(os.path.join(train_dir, label), exist_ok=True)
    os.makedirs(os.path.join(val_dir, label), exist_ok=True)
    os.makedirs(os.path.join(test_dir, label), exist_ok=True)

    # Đường dẫn tới các tệp thuộc nhãn hiện tại
    label_files = [file for file in os.listdir(data_dir) if file.startswith(label)]
    print(data_dir)
    print(label_files)
    
    # Sắp xếp ngẫu nhiên các tệp
    random.shuffle(label_files)

    # Số lượng tệp trong từng thư mục con
    num_files = len(label_files)
    num_train = int(num_files * train_ratio)
    num_val = int(num_files * val_ratio)
    num_test = num_files - num_train - num_val

    # Chia các tệp vào các thư mục con tương ứng
    train_files = label_files[:num_train]
    val_files = label_files[num_train:num_train + num_val]
    test_files = label_files[num_train + num_val:]

    for file in train_files:
        src = os.path.join(data_dir, file)
        dst = os.path.join(train_dir, label, file)
        shutil.copy2(src, dst)

    for file in val_files:
        src = os.path.join(data_dir, file)
        dst = os.path.join(val_dir, label, file)
        shutil.copy2(src, dst)

    for file in test_files:
        src = os.path.join(data_dir, file)
        dst = os.path.join(test_dir, label, file)
        shutil.copy2(src, dst)
# Out:
# Dataset/dataset_2000
# ['mild_101.jpg', 'mild_102.jpg', 'mild_105.jpg', 'mild_106.jpg', 'mild_107.jpg', 'mild_111.jpg', 'mild_122.jpg', 'mild_130.jpg', 'mild_133.jpg', 'mild_140.jpg', 'mild_142.jpg', 'mild_143.jpg', 'mild_146.jpg', 'mild_147.jpg', 'mild_149.jpg', 'mild_150.jpg', 'mild_152.jpg', 'mild_156.jpg', 'mild_158.jpg', 'mild_16.jpg', 'mild_161.jpg', 'mild_165.jpg', 'mild_166.jpg', 'mild_167.jpg', 'mild_168.jpg', 'mild_169.jpg', 'mild_172.jpg', 'mild_174.jpg', 'mild_175.jpg', 'mild_177.jpg', 'mild_178.jpg', 'mild_179.jpg', 'mild_18.jpg', 'mild_180.jpg', 'mild_183.jpg', 'mild_194.jpg', 'mild_195.jpg', 'mild_197.jpg', 'mild_2.jpg', 'mild_200.jpg', 'mild_203.jpg', 'mild_208.jpg', 'mild_213.jpg', 'mild_217.jpg', 'mild_218.jpg', 'mild_22.jpg', 'mild_221.jpg', 'mild_229.jpg', 'mild_233.jpg', 'mild_234.jpg', 'mild_238.jpg', 'mild_24.jpg', 'mild_248.jpg', 'mild_249.jpg', 'mild_250.jpg', 'mild_253.jpg', 'mild_255.jpg', 'mild_256.jpg', 'mild_26.jpg', 'mild_264.jpg', 'mild_265.jpg', 'mild_266.jpg', 'mild_267.jpg', 'mild_268.jpg', 'mild_271.jpg', 'mild_272.jpg', 'mild_282.jpg', 'mild_283.jpg', 'mild_286.jpg', 'mild_29.jpg', 'mild_290.jpg', 'mild_292.jpg', 'mild_295.jpg', 'mild_297.jpg', 'mild_3.jpg', 'mild_300.jpg', 'mild_301.jpg', 'mild_302.jpg', 'mild_303.jpg', 'mild_304.jpg', 'mild_308.jpg', 'mild_310.jpg', 'mild_316.jpg', 'mild_318.jpg', 'mild_321.jpg', 'mild_324.jpg', 'mild_329.jpg', 'mild_331.jpg', 'mild_332.jpg', 'mild_338.jpg', 'mild_34.jpg', 'mild_344.jpg', 'mild_352.jpg', 'mild_357.jpg', 'mild_36.jpg', 'mild_360.jpg', 'mild_368.jpg', 'mild_372.jpg', 'mild_374.jpg', 'mild_378.jpg', 'mild_380.jpg', 'mild_381.jpg', 'mild_382.jpg', 'mild_383.jpg', 'mild_386.jpg', 'mild_387.jpg', 'mild_389.jpg', 'mild_390.jpg', 'mild_393.jpg', 'mild_395.jpg', 'mild_396.jpg', 'mild_398.jpg', 'mild_399.jpg', 'mild_4.jpg', 'mild_40.jpg', 'mild_408.jpg', 'mild_412.jpg', 'mild_414.jpg', 'mild_416.jpg', 'mild_420.jpg', 'mild_428.jpg', 'mild_430.jpg', 'mild_432.jpg', 'mild_435.jpg', 'mild_440.jpg', 'mild_441.jpg', 'mild_442.jpg', 'mild_443.jpg', 'mild_448.jpg', 'mild_450.jpg', 'mild_452.jpg', 'mild_453.jpg', 'mild_454.jpg', 'mild_46.jpg', 'mild_461.jpg', 'mild_462.jpg', 'mild_465.jpg', 'mild_468.jpg', 'mild_47.jpg', 'mild_473.jpg', 'mild_478.jpg', 'mild_479.jpg', 'mild_485.jpg', 'mild_486.jpg', 'mild_49.jpg', 'mild_496.jpg', 'mild_5.jpg', 'mild_503.jpg', 'mild_505.jpg', 'mild_51.jpg', 'mild_511.jpg', 'mild_513.jpg', 'mild_515.jpg', 'mild_530.jpg', 'mild_536.jpg', 'mild_541.jpg', 'mild_545.jpg', 'mild_55.jpg', 'mild_552.jpg', 'mild_553.jpg', 'mild_555.jpg', 'mild_557.jpg', 'mild_559.jpg', 'mild_56.jpg', 'mild_560.jpg', 'mild_562.jpg', 'mild_564.jpg', 'mild_565.jpg', 'mild_566.jpg', 'mild_567.jpg', 'mild_574.jpg', 'mild_575.jpg', 'mild_577.jpg', 'mild_578.jpg', 'mild_581.jpg', 'mild_583.jpg', 'mild_584.jpg', 'mild_588.jpg', 'mild_589.jpg', 'mild_59.jpg', 'mild_591.jpg', 'mild_592.jpg', 'mild_596.jpg', 'mild_60.jpg', 'mild_600.jpg', 'mild_601.jpg', 'mild_604.jpg', 'mild_606.jpg', 'mild_607.jpg', 'mild_608.jpg', 'mild_615.jpg', 'mild_616.jpg', 'mild_618.jpg', 'mild_623.jpg', 'mild_626.jpg', 'mild_630.jpg', 'mild_632.jpg', 'mild_633.jpg', 'mild_634.jpg', 'mild_637.jpg', 'mild_642.jpg', 'mild_646.jpg', 'mild_647.jpg', 'mild_656.jpg', 'mild_657.jpg', 'mild_663.jpg', 'mild_664.jpg', 'mild_67.jpg', 'mild_672.jpg', 'mild_677.jpg', 'mild_684.jpg', 'mild_695.jpg', 'mild_708.jpg', 'mild_710.jpg', 'mild_714.jpg', 'mild_716.jpg', 'mild_720.jpg', 'mild_722.jpg', 'mild_724.jpg', 'mild_728.jpg', 'mild_73.jpg', 'mild_730.jpg', 'mild_731.jpg', 'mild_733.jpg', 'mild_735.jpg', 'mild_737.jpg', 'mild_74.jpg', 'mild_740.jpg', 'mild_742.jpg', 'mild_745.jpg', 'mild_747.jpg', 'mild_748.jpg', 'mild_753.jpg', 'mild_758.jpg', 'mild_759.jpg', 'mild_760.jpg', 'mild_761.jpg', 'mild_763.jpg', 'mild_770.jpg', 'mild_774.jpg', 'mild_776.jpg', 'mild_781.jpg', 'mild_783.jpg', 'mild_788.jpg', 'mild_789.jpg', 'mild_795.jpg', 'mild_799.jpg', 'mild_8.jpg', 'mild_806.jpg', 'mild_807.jpg', 'mild_808.jpg', 'mild_81.jpg' ...
# Dataset/dataset_2000
# ['moderate_10.jpg', 'moderate_12.jpg', 'moderate_14.jpg', 'moderate_17.jpg', 'moderate_22.jpg', 'moderate_23.jpg', 'moderate_25.jpg', 'moderate_26.jpg', 'moderate_36.jpg', 'moderate_37.jpg', 'moderate_40.jpg', 'moderate_44.jpg', 'moderate_47.jpg', 'moderate_49.jpg', 'moderate_51.jpg', 'moderate_59.jpg', 'moderate_62.jpg', 'moderate_63.jpg', 'moderate_8.jpg']
# Dataset/dataset_2000
# ['non_1005.jpg', 'non_101.jpg', 'non_1011.jpg', 'non_1014.jpg', 'non_1019.jpg', 'non_1030.jpg', 'non_1031.jpg', 'non_1035.jpg', 'non_1037.jpg', 'non_1039.jpg', 'non_1040.jpg', 'non_1044.jpg', 'non_1045.jpg', 'non_1051.jpg', 'non_1052.jpg', 'non_1055.jpg', 'non_1057.jpg', 'non_1062.jpg', 'non_1065.jpg', 'non_1072.jpg', 'non_1075.jpg', 'non_108.jpg', 'non_1081.jpg', 'non_1084.jpg', 'non_1085.jpg', 'non_1087.jpg', 'non_1088.jpg', 'non_109.jpg', 'non_1094.jpg', 'non_1097.jpg', 'non_1098.jpg', 'non_11.jpg', 'non_110.jpg', 'non_1100.jpg', 'non_1101.jpg', 'non_1104.jpg', 'non_1106.jpg', 'non_111.jpg', 'non_1110.jpg', 'non_1112.jpg', 'non_1113.jpg', 'non_1119.jpg', 'non_1122.jpg', 'non_1128.jpg', 'non_1135.jpg', 'non_114.jpg', 'non_1144.jpg', 'non_1150.jpg', 'non_1151.jpg', 'non_1157.jpg', 'non_1166.jpg', 'non_1169.jpg', 'non_1170.jpg', 'non_1172.jpg', 'non_1173.jpg', 'non_1174.jpg', 'non_1178.jpg', 'non_118.jpg', 'non_1185.jpg', 'non_119.jpg', 'non_1190.jpg', 'non_1195.jpg', 'non_1198.jpg', 'non_1199.jpg', 'non_12.jpg', 'non_1201.jpg', 'non_1205.jpg', 'non_1207.jpg', 'non_1217.jpg', 'non_1218.jpg', 'non_1219.jpg', 'non_122.jpg', 'non_1220.jpg', 'non_1227.jpg', 'non_1229.jpg', 'non_1233.jpg', 'non_1234.jpg', 'non_1236.jpg', 'non_124.jpg', 'non_1240.jpg', 'non_1243.jpg', 'non_1244.jpg', 'non_1246.jpg', 'non_1259.jpg', 'non_1260.jpg', 'non_1261.jpg', 'non_1268.jpg', 'non_1274.jpg', 'non_1279.jpg', 'non_1281.jpg', 'non_1283.jpg', 'non_1287.jpg', 'non_1288.jpg', 'non_1291.jpg', 'non_1293.jpg', 'non_1296.jpg', 'non_1298.jpg', 'non_13.jpg', 'non_1303.jpg', 'non_1304.jpg', 'non_1305.jpg', 'non_1306.jpg', 'non_131.jpg', 'non_1312.jpg', 'non_1313.jpg', 'non_1315.jpg', 'non_1316.jpg', 'non_1317.jpg', 'non_132.jpg', 'non_1323.jpg', 'non_133.jpg', 'non_1330.jpg', 'non_1334.jpg', 'non_1338.jpg', 'non_1340.jpg', 'non_1341.jpg', 'non_1345.jpg', 'non_1346.jpg', 'non_135.jpg', 'non_1352.jpg', 'non_1353.jpg', 'non_1357.jpg', 'non_1359.jpg', 'non_136.jpg', 'non_1367.jpg', 'non_1376.jpg', 'non_1377.jpg', 'non_138.jpg', 'non_1384.jpg', 'non_1386.jpg', 'non_1390.jpg', 'non_1391.jpg', 'non_1392.jpg', 'non_1394.jpg', 'non_1395.jpg', 'non_1396.jpg', 'non_1397.jpg', 'non_140.jpg', 'non_1403.jpg', 'non_1404.jpg', 'non_1406.jpg', 'non_1407.jpg', 'non_141.jpg', 'non_1410.jpg', 'non_1414.jpg', 'non_1416.jpg', 'non_1417.jpg', 'non_1418.jpg', 'non_1419.jpg', 'non_1423.jpg', 'non_1426.jpg', 'non_1427.jpg', 'non_1431.jpg', 'non_1432.jpg', 'non_1433.jpg', 'non_1437.jpg', 'non_1439.jpg', 'non_144.jpg', 'non_1442.jpg', 'non_145.jpg', 'non_1453.jpg', 'non_1455.jpg', 'non_1456.jpg', 'non_1463.jpg', 'non_1466.jpg', 'non_1468.jpg', 'non_147.jpg', 'non_1472.jpg', 'non_1474.jpg', 'non_1476.jpg', 'non_1479.jpg', 'non_1483.jpg', 'non_1492.jpg', 'non_1495.jpg', 'non_1496.jpg', 'non_1497.jpg', 'non_15.jpg', 'non_1500.jpg', 'non_1502.jpg', 'non_1504.jpg', 'non_1505.jpg', 'non_1507.jpg', 'non_151.jpg', 'non_1512.jpg', 'non_1513.jpg', 'non_1514.jpg', 'non_1516.jpg', 'non_1517.jpg', 'non_1521.jpg', 'non_1522.jpg', 'non_1524.jpg', 'non_153.jpg', 'non_1530.jpg', 'non_1531.jpg', 'non_1532.jpg', 'non_1536.jpg', 'non_1538.jpg', 'non_1540.jpg', 'non_1542.jpg', 'non_1543.jpg', 'non_1546.jpg', 'non_1547.jpg', 'non_1554.jpg', 'non_1561.jpg', 'non_1566.jpg', 'non_1570.jpg', 'non_1572.jpg', 'non_1573.jpg', 'non_1574.jpg', 'non_1578.jpg', 'non_1579.jpg', 'non_158.jpg', 'non_1580.jpg', 'non_1584.jpg', 'non_1585.jpg', 'non_1588.jpg', 'non_1589.jpg', 'non_159.jpg', 'non_1590.jpg', 'non_1591.jpg', 'non_1592.jpg', 'non_1598.jpg', 'non_16.jpg', 'non_1600.jpg', 'non_1607.jpg', 'non_1610.jpg', 'non_1612.jpg', 'non_1619.jpg', 'non_1629.jpg', 'non_163.jpg', 'non_1630.jpg', 'non_1633.jpg', 'non_1636.jpg', 'non_1637.jpg', 'non_1638.jpg', 'non_164.jpg', 'non_1645.jpg', 'non_1646.jpg', 'non_1647.jpg', 'non_1651.jpg', 'non_1652.jpg', 'non_1655.jpg', 'non_1663.jpg', 'non_1678.jpg', 'non_1683.jpg', 'non_1684.jpg', 'non_1688.jpg', 'non_1689.jpg', 'non_169.jpg', 'non_1691.jpg', 'non_1693.jpg', 'non_1694.jpg', 'non_ ...
# Dataset/dataset_2000
# ['verymild.jpg', 'verymild_1000.jpg', 'verymild_1006.jpg', 'verymild_1007.jpg', 'verymild_1008.jpg', 'verymild_101.jpg', 'verymild_1019.jpg', 'verymild_1023.jpg', 'verymild_1029.jpg', 'verymild_103.jpg', 'verymild_1031.jpg', 'verymild_1032.jpg', 'verymild_1037.jpg', 'verymild_1038.jpg', 'verymild_104.jpg', 'verymild_1041.jpg', 'verymild_1048.jpg', 'verymild_105.jpg', 'verymild_1051.jpg', 'verymild_1054.jpg', 'verymild_1057.jpg', 'verymild_1060.jpg', 'verymild_1061.jpg', 'verymild_1063.jpg', 'verymild_1065.jpg', 'verymild_1067.jpg', 'verymild_1068.jpg', 'verymild_1071.jpg', 'verymild_1073.jpg', 'verymild_1075.jpg', 'verymild_1076.jpg', 'verymild_1077.jpg', 'verymild_108.jpg', 'verymild_1081.jpg', 'verymild_1082.jpg', 'verymild_1087.jpg', 'verymild_1089.jpg', 'verymild_1090.jpg', 'verymild_1092.jpg', 'verymild_1093.jpg', 'verymild_1099.jpg', 'verymild_11.jpg', 'verymild_110.jpg', 'verymild_1101.jpg', 'verymild_1102.jpg', 'verymild_1106.jpg', 'verymild_1107.jpg', 'verymild_1114.jpg', 'verymild_1115.jpg', 'verymild_1117.jpg', 'verymild_1121.jpg', 'verymild_1122.jpg', 'verymild_1131.jpg', 'verymild_1134.jpg', 'verymild_1137.jpg', 'verymild_1140.jpg', 'verymild_1142.jpg', 'verymild_1143.jpg', 'verymild_1145.jpg', 'verymild_1146.jpg', 'verymild_1151.jpg', 'verymild_1152.jpg', 'verymild_116.jpg', 'verymild_1162.jpg', 'verymild_1165.jpg', 'verymild_1166.jpg', 'verymild_1169.jpg', 'verymild_1171.jpg', 'verymild_1172.jpg', 'verymild_1173.jpg', 'verymild_1175.jpg', 'verymild_1177.jpg', 'verymild_1178.jpg', 'verymild_1181.jpg', 'verymild_1182.jpg', 'verymild_1183.jpg', 'verymild_1185.jpg', 'verymild_119.jpg', 'verymild_1191.jpg', 'verymild_1192.jpg', 'verymild_1194.jpg', 'verymild_1197.jpg', 'verymild_1198.jpg', 'verymild_1199.jpg', 'verymild_120.jpg', 'verymild_1201.jpg', 'verymild_1202.jpg', 'verymild_1207.jpg', 'verymild_1210.jpg', 'verymild_1212.jpg', 'verymild_1216.jpg', 'verymild_1217.jpg', 'verymild_1220.jpg', 'verymild_1221.jpg', 'verymild_1222.jpg', 'verymild_1228.jpg', 'verymild_1229.jpg', 'verymild_1231.jpg', 'verymild_1232.jpg', 'verymild_1238.jpg', 'verymild_1240.jpg', 'verymild_1242.jpg', 'verymild_1244.jpg', 'verymild_1245.jpg', 'verymild_1246.jpg', 'verymild_1247.jpg', 'verymild_1248.jpg', 'verymild_1249.jpg', 'verymild_125.jpg', 'verymild_1256.jpg', 'verymild_1257.jpg', 'verymild_1258.jpg', 'verymild_1260.jpg', 'verymild_1261.jpg', 'verymild_1277.jpg', 'verymild_1282.jpg', 'verymild_1283.jpg', 'verymild_1289.jpg', 'verymild_1293.jpg', 'verymild_1295.jpg', 'verymild_1301.jpg', 'verymild_1302.jpg', 'verymild_1304.jpg', 'verymild_1306.jpg', 'verymild_1308.jpg', 'verymild_1311.jpg', 'verymild_1315.jpg', 'verymild_1317.jpg', 'verymild_133.jpg', 'verymild_1333.jpg', 'verymild_1335.jpg', 'verymild_1337.jpg', 'verymild_1340.jpg', 'verymild_1341.jpg', 'verymild_1342.jpg', 'verymild_1346.jpg', 'verymild_1347.jpg', 'verymild_1351.jpg', 'verymild_1361.jpg', 'verymild_1362.jpg', 'verymild_1363.jpg', 'verymild_1367.jpg', 'verymild_1369.jpg', 'verymild_1372.jpg', 'verymild_1373.jpg', 'verymild_1381.jpg', 'verymild_1383.jpg', 'verymild_1387.jpg', 'verymild_139.jpg', 'verymild_1391.jpg', 'verymild_1398.jpg', 'verymild_1401.jpg', 'verymild_1402.jpg', 'verymild_1406.jpg', 'verymild_1407.jpg', 'verymild_1410.jpg', 'verymild_1419.jpg', 'verymild_1423.jpg', 'verymild_1427.jpg', 'verymild_1428.jpg', 'verymild_1430.jpg', 'verymild_1437.jpg', 'verymild_144.jpg', 'verymild_1443.jpg', 'verymild_1446.jpg', 'verymild_1448.jpg', 'verymild_1457.jpg', 'verymild_1458.jpg', 'verymild_1460.jpg', 'verymild_1463.jpg', 'verymild_1467.jpg', 'verymild_147.jpg', 'verymild_1471.jpg', 'verymild_1472.jpg', 'verymild_1473.jpg', 'verymild_1478.jpg', 'verymild_1479.jpg', 'verymild_1481.jpg', 'verymild_1484.jpg', 'verymild_1488.jpg', 'verymild_1494.jpg', 'verymild_1495.jpg', 'verymild_1496.jpg', 'verymild_1499.jpg', 'verymild_1502.jpg', 'verymild_1503.jpg', 'verymild_1504.jpg', 'verymild_1506.jpg', 'verymild_1507.jpg', 'verymild_1508.jpg', 'verymild_1514.jpg', 'verymild ...
