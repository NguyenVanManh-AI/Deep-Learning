# %%
# Thêm thư viện
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report , confusion_matrix
from imutils import paths
from keras.applications import VGG16
from keras.applications import imagenet_utils
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import numpy as np
import random
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Lấy các đường dẫn đến ảnh.
image_path = list(paths.list_images('dataset/'))
print(image_path)
# Đổi vị trí ngẫu nhiên các đường dẫn ảnh
random.shuffle(image_path)
# Out:
# ['dataset/Bluebell\\image_0241.jpg', 'dataset/Bluebell\\image_0242.jpg', 'dataset/Bluebell\\image_0243.jpg', 'dataset/Bluebell\\image_0244.jpg', 'dataset/Bluebell\\image_0245.jpg', 'dataset/Bluebell\\image_0246.jpg', 'dataset/Bluebell\\image_0247.jpg', 'dataset/Bluebell\\image_0248.jpg', 'dataset/Bluebell\\image_0249.jpg', 'dataset/Bluebell\\image_0250.jpg', 'dataset/Bluebell\\image_0251.jpg', 'dataset/Bluebell\\image_0252.jpg', 'dataset/Bluebell\\image_0253.jpg', 'dataset/Bluebell\\image_0254.jpg', 'dataset/Bluebell\\image_0255.jpg', 'dataset/Bluebell\\image_0256.jpg', 'dataset/Bluebell\\image_0257.jpg', 'dataset/Bluebell\\image_0258.jpg', 'dataset/Bluebell\\image_0259.jpg', 'dataset/Bluebell\\image_0260.jpg', 'dataset/Bluebell\\image_0261.jpg', 'dataset/Bluebell\\image_0262.jpg', 'dataset/Bluebell\\image_0263.jpg', 'dataset/Bluebell\\image_0264.jpg', 'dataset/Bluebell\\image_0265.jpg', 'dataset/Bluebell\\image_0266.jpg', 'dataset/Bluebell\\image_0267.jpg', 'dataset/Bluebell\\image_0268.jpg', 'dataset/Bluebell\\image_0269.jpg', 'dataset/Bluebell\\image_0270.jpg', 'dataset/Bluebell\\image_0271.jpg', 'dataset/Bluebell\\image_0272.jpg', 'dataset/Bluebell\\image_0273.jpg', 'dataset/Bluebell\\image_0274.jpg', 'dataset/Bluebell\\image_0275.jpg', 'dataset/Bluebell\\image_0276.jpg', 'dataset/Bluebell\\image_0277.jpg', 'dataset/Bluebell\\image_0278.jpg', 'dataset/Bluebell\\image_0279.jpg', 'dataset/Bluebell\\image_0280.jpg', 'dataset/Bluebell\\image_0281.jpg', 'dataset/Bluebell\\image_0282.jpg', 'dataset/Bluebell\\image_0283.jpg', 'dataset/Bluebell\\image_0284.jpg', 'dataset/Bluebell\\image_0285.jpg', 'dataset/Bluebell\\image_0286.jpg', 'dataset/Bluebell\\image_0287.jpg', 'dataset/Bluebell\\image_0288.jpg', 'dataset/Bluebell\\image_0289.jpg', 'dataset/Bluebell\\image_0290.jpg', 'dataset/Bluebell\\image_0291.jpg', 'dataset/Bluebell\\image_0292.jpg', 'dataset/Bluebell\\image_0293.jpg', 'dataset/Bluebell\\image_0294.jpg', 'dataset/Bluebell\\image_0295.jpg', 'dataset/Bluebell\\image_0296.jpg', 'dataset/Bluebell\\image_0297.jpg', 'dataset/Bluebell\\image_0298.jpg', 'dataset/Bluebell\\image_0299.jpg', 'dataset/Bluebell\\image_0300.jpg', 'dataset/Bluebell\\image_0301.jpg', 'dataset/Bluebell\\image_0302.jpg', 'dataset/Bluebell\\image_0303.jpg', 'dataset/Bluebell\\image_0304.jpg', 'dataset/Bluebell\\image_0305.jpg', 'dataset/Bluebell\\image_0306.jpg', 'dataset/Bluebell\\image_0307.jpg', 'dataset/Bluebell\\image_0308.jpg', 'dataset/Bluebell\\image_0309.jpg', 'dataset/Bluebell\\image_0310.jpg', 'dataset/Bluebell\\image_0311.jpg', 'dataset/Bluebell\\image_0312.jpg', 'dataset/Bluebell\\image_0313.jpg', 'dataset/Bluebell\\image_0314.jpg', 'dataset/Bluebell\\image_0315.jpg', 'dataset/Bluebell\\image_0316.jpg', 'dataset/Bluebell\\image_0317.jpg', 'dataset/Bluebell\\image_0318.jpg', 'dataset/Bluebell\\image_0319.jpg', 'dataset/Bluebell\\image_0320.jpg', 'dataset/Buttercup\\image_1121.jpg', 'dataset/Buttercup\\image_1122.jpg', 'dataset/Buttercup\\image_1123.jpg', 'dataset/Buttercup\\image_1124.jpg', 'dataset/Buttercup\\image_1125.jpg', 'dataset/Buttercup\\image_1126.jpg', 'dataset/Buttercup\\image_1127.jpg', 'dataset/Buttercup\\image_1128.jpg', 'dataset/Buttercup\\image_1129.jpg', 'dataset/Buttercup\\image_1130.jpg', 'dataset/Buttercup\\image_1131.jpg', 'dataset/Buttercup\\image_1132.jpg', 'dataset/Buttercup\\image_1133.jpg', 'dataset/Buttercup\\image_1134.jpg', 'dataset/Buttercup\\image_1135.jpg', 'dataset/Buttercup\\image_1136.jpg', 'dataset/Buttercup\\image_1137.jpg', 'dataset/Buttercup\\image_1138.jpg', 'dataset/Buttercup\\image_1139.jpg', 'dataset/Buttercup\\image_1140.jpg', 'dataset/Buttercup\\image_1141.jpg', 'dataset/Buttercup\\image_1142.jpg', 'dataset/Buttercup\\image_1143.jpg', 'dataset/Buttercup\\image_1144.jpg', 'dataset/Buttercup\\image_1145.jpg', 'dataset/Buttercup\\image_1146.jpg', 'dataset/Buttercup\\image_1147.jpg', 'dataset/Buttercup\\image_1148.jpg', 'dataset/Buttercup\\image_1149.jpg', 'dataset/Buttercup\\image_1150.jpg', 'dataset/ ...

# %%
# Đường dẫn ảnh sẽ là dataset/tên_loài_hoa/tên_ảnh ví dụ dataset/Bluebell/image_0241.jpg nên p.split(os.path.sep)[-2] sẽ lấy ra được tên loài hoa
labels = [p.split(os.path.sep)[-2] for p in image_path]
print(labels)
# Chuyển tên các loài hoa thành số
le = LabelEncoder()
labels = le.fit_transform(labels)
# Out:
# ['dataset/LilyValley', 'dataset/Dandelion', 'dataset/Iris', 'dataset/Tulip', 'dataset/LilyValley', 'dataset/Daisy', 'dataset/Tigerlily', 'dataset/Bluebell', 'dataset/Tigerlily', 'dataset/Tulip', 'dataset/Snowdrop', 'dataset/Crocus', 'dataset/Buttercup', 'dataset/Sunflower', 'dataset/ColtsFoot', 'dataset/LilyValley', 'dataset/Iris', 'dataset/Tulip', 'dataset/Windflower', 'dataset/Daisy', 'dataset/Daffodil', 'dataset/Crocus', 'dataset/ColtsFoot', 'dataset/Tulip', 'dataset/Tigerlily', 'dataset/Pansy', 'dataset/Tulip', 'dataset/Crocus', 'dataset/Tulip', 'dataset/Bluebell', 'dataset/Windflower', 'dataset/Fritillary', 'dataset/Daffodil', 'dataset/Sunflower', 'dataset/Daffodil', 'dataset/LilyValley', 'dataset/Dandelion', 'dataset/Cowslip', 'dataset/Iris', 'dataset/LilyValley', 'dataset/Sunflower', 'dataset/Dandelion', 'dataset/Daffodil', 'dataset/Pansy', 'dataset/LilyValley', 'dataset/Crocus', 'dataset/Fritillary', 'dataset/Windflower', 'dataset/Tulip', 'dataset/Snowdrop', 'dataset/Iris', 'dataset/Dandelion', 'dataset/Buttercup', 'dataset/Daffodil', 'dataset/Windflower', 'dataset/Daffodil', 'dataset/Cowslip', 'dataset/Pansy', 'dataset/Fritillary', 'dataset/Daisy', 'dataset/LilyValley', 'dataset/Pansy', 'dataset/Cowslip', 'dataset/Cowslip', 'dataset/Snowdrop', 'dataset/Fritillary', 'dataset/Crocus', 'dataset/Daisy', 'dataset/Bluebell', 'dataset/Snowdrop', 'dataset/Pansy', 'dataset/Pansy', 'dataset/Daffodil', 'dataset/Bluebell', 'dataset/Windflower', 'dataset/Cowslip', 'dataset/Windflower', 'dataset/Buttercup', 'dataset/Crocus', 'dataset/LilyValley', 'dataset/Tulip', 'dataset/Crocus', 'dataset/Crocus', 'dataset/Tigerlily', 'dataset/Dandelion', 'dataset/ColtsFoot', 'dataset/Iris', 'dataset/Dandelion', 'dataset/Bluebell', 'dataset/Tulip', 'dataset/Bluebell', 'dataset/ColtsFoot', 'dataset/Windflower', 'dataset/Buttercup', 'dataset/Tigerlily', 'dataset/Daffodil', 'dataset/Dandelion', 'dataset/Dandelion', 'dataset/Iris', 'dataset/Buttercup', 'dataset/LilyValley', 'dataset/Cowslip', 'dataset/Windflower', 'dataset/Tigerlily', 'dataset/Sunflower', 'dataset/Sunflower', 'dataset/Daisy', 'dataset/Tigerlily', 'dataset/Iris', 'dataset/ColtsFoot', 'dataset/Buttercup', 'dataset/Daisy', 'dataset/Dandelion', 'dataset/Fritillary', 'dataset/Fritillary', 'dataset/Sunflower', 'dataset/Windflower', 'dataset/Iris', 'dataset/Tulip', 'dataset/Daffodil', 'dataset/Iris', 'dataset/Daisy', 'dataset/Buttercup', 'dataset/Snowdrop', 'dataset/Crocus', 'dataset/Pansy', 'dataset/Pansy', 'dataset/Pansy', 'dataset/Pansy', 'dataset/Pansy', 'dataset/Cowslip', 'dataset/Crocus', 'dataset/Tulip', 'dataset/ColtsFoot', 'dataset/Cowslip', 'dataset/Tigerlily', 'dataset/Bluebell', 'dataset/Fritillary', 'dataset/ColtsFoot', 'dataset/Sunflower', 'dataset/Daisy', 'dataset/Sunflower', 'dataset/Crocus', 'dataset/Bluebell', 'dataset/Pansy', 'dataset/Snowdrop', 'dataset/Cowslip', 'dataset/Daffodil', 'dataset/Cowslip', 'dataset/LilyValley', 'dataset/Tulip', 'dataset/Buttercup', 'dataset/Snowdrop', 'dataset/ColtsFoot', 'dataset/Daffodil', 'dataset/Fritillary', 'dataset/Dandelion', 'dataset/Windflower', 'dataset/ColtsFoot', 'dataset/Fritillary', 'dataset/Tigerlily', 'dataset/Daisy', 'dataset/Tulip', 'dataset/LilyValley', 'dataset/Cowslip', 'dataset/Buttercup', 'dataset/Buttercup', 'dataset/Iris', 'dataset/Tulip', 'dataset/Buttercup', 'dataset/Daisy', 'dataset/Daffodil', 'dataset/Iris', 'dataset/Cowslip', 'dataset/Cowslip', 'dataset/Dandelion', 'dataset/Daffodil', 'dataset/Daisy', 'dataset/Tulip', 'dataset/Iris', 'dataset/Bluebell', 'dataset/Dandelion', 'dataset/Daisy', 'dataset/Buttercup', 'dataset/Windflower', 'dataset/Fritillary', 'dataset/Crocus', 'dataset/Crocus', 'dataset/Buttercup', 'dataset/Bluebell', 'dataset/Tigerlily', 'dataset/Snowdrop', 'dataset/Daffodil', 'dataset/Daisy', 'dataset/Windflower', 'dataset/Bluebell', 'dataset/LilyValley', 'dataset/Crocus', 'dataset/Fritillary', 'dataset/Fritillary', 'dataset/Daisy', 'dataset/Pansy', 'dataset/Sunflower', 'dataset/Fritillary', 'datase ...

# %% [markdown]
# #### Load model VGG 16 của ImageNet dataset, include_top=False để bỏ phần Fully connected layer ở cuối.

# %%
# Load model VGG 16 của ImageNet dataset, include_top=False để bỏ phần Fully connected layer ở cuối.
model = VGG16(weights='imagenet', include_top=False)

# %% [markdown]
# -	Lưu ý : Kích thước của ảnh cũng chính là kích thước của dữ liệu sau khi chuyển thành ma trận, ví dụ ảnh có kích thước là 28*28 thì khi chuyển thành ma trận sẽ là 28*28*3 nếu là ảnh màu và 28*28*1 nếu là ảnh xám . Nếu transfer learning model thì phải điều chỉnh lại kích thước sao cho phù hợp với đầu vào của model đó .

# %% [markdown]
# Dòng code này lặp qua từng đường dẫn ảnh trong danh sách `image_path`, sau đó thực hiện các bước tiền xử lý ảnh như sau:
#
# 1. Sử dụng hàm `load_img` để tải ảnh và resize về kích thước (224, 224).
# 2. Sử dụng hàm `img_to_array` để chuyển ảnh thành một mảng numpy.
# 3. Mở rộng chiều của mảng numpy sử dụng `np.expand_dims` để tạo thành một batch có kích thước (1, 224, 224, 3).
# 4. Tiền xử lý ảnh sử dụng `imagenet_utils.preprocess_input` để chuẩn bị cho việc đưa vào mô hình VGG16.
# 5. Thêm ảnh đã tiền xử lý vào danh sách `list_image`.
# 6. Cuối cùng, chuyển danh sách các ảnh thành một mảng numpy một chiều bằng cách sử dụng `np.vstack`.

# %%
# Load ảnh và resize về đúng kích thước mà VGG 16 cần là (224,224)
list_image = []
for (j, imagePath) in enumerate(image_path):
    # Load ảnh và resize về kích thước (224, 224)
    image = load_img(imagePath, target_size=(224, 224))
    
    # Chuyển ảnh thành mảng numpy
    image = img_to_array(image)
    
    # Mở rộng chiều của mảng numpy
    image = np.expand_dims(image, 0)
    
    # Tiền xử lý ảnh theo tiêu chuẩn của mô hình VGG16
    image = imagenet_utils.preprocess_input(image)
    
    # Thêm ảnh đã tiền xử lý vào danh sách
    list_image.append(image)
    
# Chuyển danh sách các ảnh thành mảng numpy một chiều
list_image = np.vstack(list_image)

# %%
# Dùng pre-trained model để lấy ra các feature của ảnh 
features = model.predict(list_image)

# Giống bước flatten trong CNN, chuyển từ tensor 3 chiều sau ConvNet sang vector 1 chiều
features = features.reshape((features.shape[0], 512*7*7))
# Out:
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step

# %% [markdown]
#     # features = model.predict(list_image) => cho ra vector đặc trưng chứ không phải là one-hot

# %% [markdown]
# NHẮT LẠI : C:\Users\ADMIN\Downloads\DeepLearning\Learning\Chapter4_CNN\Lab4_MNIST_Detail.ipynb
# ![image.png](attachment:image.png)
# Trong ví dụ trên, bạn đã sử dụng mô hình để dự đoán một ảnh từ tập dữ liệu kiểm tra. Khi bạn gọi `model.predict(X_test[100].reshape(1,28,28,1))`, mô hình sẽ dự đoán lớp của ảnh được truyền vào. Kết quả trả về là một vector xác suất cho mỗi lớp có thể có. Trong trường hợp này, vector đó có 10 phần tử, mỗi phần tử thể hiện xác suất của mỗi lớp từ 0 đến 9.
#
# Sau đó, bạn sử dụng `np.argmax(y_predict)` để tìm ra chỉ mục của phần tử có giá trị lớn nhất trong vector xác suất. Chỉ mục này tương ứng với lớp mà mô hình dự đoán cho ảnh đó. Trong trường hợp của bạn, chỉ mục đó là 6, nghĩa là mô hình dự đoán rằng ảnh đó chứa chữ số 6.

# %% [markdown]
# #### Ta có danh sách vector đặc trưng và label tương ứng của các vector đặc trưng , giờ chia nó ra thành dữ liệu để huấn luyện

# %%
# Chia traing set, test set tỉ lệ 80-20
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# %% [markdown]
# Dòng code này thực hiện tìm kiếm lưới (grid search) để tìm ra các siêu tham số tốt nhất cho mô hình. Cụ thể:
#
# - `params` là một từ điển chứa các giá trị của các siêu tham số cần tinh chỉnh. Trong trường hợp này, chúng ta tinh chỉnh siêu tham số `C`, là hệ số trong regularization.
# - `GridSearchCV` là một công cụ từ thư viện scikit-learn giúp tìm ra các siêu tham số tối ưu bằng cách thử tất cả các tổ hợp có thể từ các giá trị đã chỉ định.
# - `LogisticRegression()` tạo ra một mô hình hồi quy logistic mà chúng ta muốn tinh chỉnh.
# - `model.fit(X_train, y_train)` thực hiện việc huấn luyện mô hình trên tập dữ liệu huấn luyện để tìm ra các giá trị siêu tham số tốt nhất.
# - `model.best_params_` trả về các giá trị tối ưu nhất cho các siêu tham số được tìm thấy.
#
# Kết quả là `model.best_params_` sẽ chứa các giá trị tối ưu nhất cho siêu tham số `C`.

# %%
# Grid search để tìm các parameter tốt nhất cho model. C = 1/lamda, hệ số trong regularisation. Solver là kiểu optimize
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html
params = {'C' : [0.1, 1.0, 10.0, 100.0]}
#model = GridSearchCV(LogisticRegression(solver='lbfgs', multi_class='multinomial'), params)
model = GridSearchCV(LogisticRegression(), params) # KHỞI TẠO MODEL 
model.fit(X_train, y_train) # HUẤN LUYỆN MODEL 
print('Best parameter for the model {}'.format(model.best_params_))
# Out:
# Best parameter for the model {'C': 0.1}

# %%
print("Best parameters for the model:", model.best_params_)
print("Best estimator:", model.best_estimator_)
# Out:
# Best parameters for the model: {'C': 0.1}
# Best estimator: LogisticRegression(C=0.1)

# %%
# Đánh giá model
preds = model.predict(X_test) # DỰ ĐOÁN VÀ ĐÁNH GIÁ 
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88        14
#            1       1.00      0.79      0.88        19
#            2       1.00      1.00      1.00        16
#            3       0.59      1.00      0.74        16
#            4       0.89      0.94      0.91        17
#            5       1.00      0.70      0.82        10
#            6       1.00      0.93      0.96        14
#            7       1.00      1.00      1.00        10
#            8       0.94      1.00      0.97        17
#            9       1.00      0.82      0.90        22
#           10       0.94      0.85      0.89        20
#           11       1.00      0.92      0.96        13
#           12       0.80      0.89      0.84        18
#           13       1.00      1.00      1.00        14
#           14       1.00      0.94      0.97        16
#           15       0.92      0.75      0.83        16
#           16       0.95      0.95      0.95        20
#
#     accuracy                           0.91       272
#    macro avg       0.93      0.91      0.91       272
# weighted avg       0.93      0.91      0.91       272

# %%
# Tạo ma trận nhầm lẫn
cm = confusion_matrix(y_test, preds)

# Chuyển nhãn số thành tên loài hoa
label_names = le.inverse_transform(np.unique(y_test))
label_names = [label.split('/')[-1] for label in label_names]

# Sắp xếp lại ma trận nhầm lẫn
sorted_cm = cm[np.argsort(label_names)][:, np.argsort(label_names)]

# Tạo dataframe từ ma trận nhầm lẫn đã sắp xếp lại
df_cm = pd.DataFrame(sorted_cm, index=label_names, columns=label_names)

# Vẽ ma trận nhầm lẫn
plt.figure(figsize=(10, 8))
sns.heatmap(df_cm, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.show()
